# %% [markdown]
# # Statistics Advance-2

# %% [markdown]
# #### Assignment Questions

# %% [markdown]
# Q1.What are the proability Mass function (PMF)and Probability Density Function(PDF).Explain with an example.

# %% [markdown]
# Ans:
# Probability Mass Function (PMF) and Probability Density Function (PDF) are both mathematical concepts used in probability theory to describe the likelihood of different outcomes in a random process. However, they are different in nature and application.
#
# A Probability Mass Function (PMF) is used to describe the probability distribution of a discrete random variable, which takes on a finite or countable set of values. In other words, it is a function that maps each possible value of a discrete random variable to its probability of occurrence. The sum of all probabilities must equal 1.
#
# For example, consider rolling a fair six-sided die. The possible outcomes are 1, 2, 3, 4, 5, and 6. The PMF of this experiment would be:
#
# P(X = 1) = 1/6
# P(X = 2) = 1/6
# P(X = 3) = 1/6
# P(X = 4) = 1/6
# P(X = 5) = 1/6
# P(X = 6) = 1/6
#
# Where X is the random variable representing the outcome of the roll.
#
# On the other hand, a Probability Density Function (PDF) is used to describe the probability distribution of a continuous random variable, which can take on any value within a certain range. In other words, it is a function that maps each possible value of a continuous random variable to its probability density, which represents the relative likelihood of that value occurring. The integral of the PDF over its range must equal 1.
#
# For example, consider the height of adult humans. The height is a continuous random variable that can take on any value within a certain range. The PDF of this variable would be a function that describes the relative likelihood of different heights occurring. However, it is impossible for any two individuals to have the exact same height, so the height is continuous, not discrete.
#
# It is important to note that the PMF and PDF are both used to describe the probability distribution of random variables, but they have different mathematical properties and interpretations. The PMF can be used to calculate the expected value and variance of a discrete random variable, while the PDF can be used to calculate the expected value and variance of a continuous random variable.

# %% [markdown]
# Q2.What is Cumulative Density Fuction (CDF)?Explain with an example,why CDF is used?

# %% [markdown]
# A cumulative distribution function (CDF) is a function that gives the cumulative probability of a random variable taking on a value less than or equal to a given value. In other words, it gives the probability that a random variable X is less than or equal to x for all possible values of x. The CDF is an important concept in probability theory and is used to describe the distribution of a random variable.
#
# Here's an example to illustrate the concept of CDF:
#
# Suppose we have a random variable X that represents the height of adult males in a population. The CDF of X gives the probability that a randomly selected male from the population will be less than or equal to a given height.
#
# For example, if we plot the CDF of X, the value of the CDF at a height of 180 cm would represent the probability that a randomly selected male from the population will be 180 cm or shorter in height. Similarly, the value of the CDF at a height of 190 cm would represent the probability that a randomly selected male from the population will be 190 cm or shorter in height.
#
# The CDF is useful for several reasons. First, it provides a complete description of the probability distribution of a random variable, which can be used to calculate various statistical measures such as the mean, variance, and percentiles of the distribution. Second, it allows us to calculate the probability of a random variable falling within a particular range of values. Finally, it can be used to compare and contrast different probability distributions, which can be useful for model selection and hypothesis testing in statistical analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The normal distribution is a commonly used statistical model that is suitable for a wide range of applications. Some examples of situations where the normal distribution might be used as a model include:
#
# Heights of people: The heights of people in a population are often normally distributed, with a mean height and a standard deviation that describe the average height and the variability of heights within the population.
#
# IQ scores: IQ scores are often normally distributed, with a mean IQ and a standard deviation that describe the average intelligence and the variability of intelligence within the population.
#
# Test scores: Test scores, such as SAT scores or GRE scores, are often normally distributed, with a mean score and a standard deviation that describe the average performance and the variability of performance within the population.
#
# Errors in measurement: Errors in measurement, such as errors in a laboratory experiment or errors in a manufacturing process, are often normally distributed, with a mean error and a standard deviation that describe the average amount of error and the variability of error within the measurement process.
#
# The parameters of the normal distribution, namely the mean (µ) and standard deviation (σ), determine the shape of the distribution. The mean specifies the location of the peak of the distribution, while the standard deviation specifies the width of the distribution. A larger standard deviation corresponds to a wider distribution, which indicates greater variability in the data. Similarly, a smaller standard deviation corresponds to a narrower distribution, which indicates less variability in the data. Overall, the mean and standard deviation together determine the shape, location, and spread of the normal distribution.

# %% [markdown]
# Q4.Explain the importance of Normal distribution,gie a few real-life examples of normal distribution.

# %% [markdown]
# Normal distribution is an important concept in statistics because it is a model that is often used to describe real-life data. The normal distribution is also known as the Gaussian distribution or bell curve and it is characterized by its mean (µ) and standard deviation (σ). The importance of normal distribution can be explained as follows:
#
# It is a widely applicable model: The normal distribution is applicable in various fields such as physics, engineering, economics, psychology, and biology, among others. This is because many naturally occurring phenomena follow a normal distribution.
#
# It simplifies analysis: Many statistical tests and models rely on the assumption that the data is normally distributed. When data follows a normal distribution, it becomes easier to analyze, make predictions and draw conclusions.
#
# It enables better decision making: Understanding the normal distribution and its properties can help in making informed decisions in a variety of contexts. For instance, a manufacturer might use the normal distribution to make decisions about product quality, while a financial analyst might use it to analyze investment returns.
#
# Examples of real-life situations where normal distribution is observed include:
#
# Heights and weights of people in a population
# IQ scores
# Test scores
# Blood pressure measurements
# Reaction times of people
# Shoe sizes
# Body temperature
# The distribution of IQ scores in a given population
# The time taken to complete a task
# The number of flaws per unit in a manufacturing process
# In summary, the normal distribution is important because it is widely applicable, simplifies analysis, and enables better decision-making. Real-life examples of normal distribution can be found in many different fields, including science, economics, and social sciences.

# %% [markdown]
# Q5.what is bernaulli distribution? Give an example. what is the difference between bernaulli distribution and binomail distribution

# %% [markdown]
# Bernoulli distribution is a discrete probability distribution that describes a random variable that takes on only two possible values, usually labeled as 0 and 1. It is named after Swiss mathematician Jacob Bernoulli, who introduced it in the early 18th century.
#
# In Bernoulli distribution, the parameter p represents the probability of success (1) in a single trial, while the probability of failure (0) is 1-p. Thus, the probability mass function of the Bernoulli distribution is given by:
#
# P(X=x) = p^x (1-p)^(1-x)
#
# where X is the random variable that takes on values 0 or 1, and x is either 0 or 1.
#
# An example of a situation that can be modeled by a Bernoulli distribution is the outcome of a coin flip, where success is defined as the coin landing heads up, and failure as it landing tails up.
#
# The difference between Bernoulli and binomial distributions is that the Bernoulli distribution models the outcome of a single trial with only two possible outcomes (success or failure), while the binomial distribution models the number of successes in a fixed number of independent Bernoulli trials.
#
# In other words, while the Bernoulli distribution describes the probability of obtaining a single success or failure, the binomial distribution describes the probability of obtaining a certain number of successes in a given number of independent trials. The binomial distribution has two parameters: n, which is the number of trials, and p, which is the probability of success in each trial.
#
# In summary, the Bernoulli distribution is a discrete probability distribution that describes a random variable with only two possible outcomes, while the binomial distribution describes the number of successes in a fixed number of independent Bernoulli trials.

# %% [markdown]
# Q6.Consider a dataset with a mean of 50 and standard deviation of 10.if we assume that the dataset is normally distributed,what is the probability that a randomly selected observation will be greaer than 60? use the appropriate formula ans how your calculations.

# %% [markdown]
# - Ans:
#
# To find the probability that a randomly selected observation from a normally distributed dataset with mean 50 and standard deviation 10 will be greater than 60, we need to use the standard normal distribution formula and standardize the value of 60.
#
# The standard normal distribution has a mean of 0 and a standard deviation of 1, so we need to transform our dataset to this standard distribution. We can do this by using the formula:
#
# z = (x - mu) / sigma
#
# where z is the standardized value, x is the observed value, mu is the mean, and sigma is the standard deviation.
#
# Plugging in our values, we get:
#
# z = (60 - 50) / 10
# z = 1
#
# Now, we need to find the area under the standard normal distribution curve to the right of z = 1. We can use a standard normal distribution table or calculator to find this probability. The probability of a standard normal distribution being greater than 1 is approximately 0.1587.
#
# Therefore, the probability that a randomly selected observation from the given dataset will be greater than 60 is 0.1587 or approximately 16%.

# %% [markdown]
# Q7: Explain uniform Distribution with an example.

# %% [markdown]
# Uniform distribution is a probability distribution where all values in the distribution have an equal probability of occurring.
#
# In a uniform distribution, the probability density function (PDF) is a constant value within a given range of values, and zero outside that range.
#
# A common example of a uniform distribution is rolling a fair die, where each number on the die has an equal probability of being rolled.
#
# Another example is choosing a random number between 1 and 10, where each number has an equal probability of being chosen.
#
# The mean of a uniform distribution is the average of the minimum and maximum values of the distribution.
#
# The variance of a uniform distribution is given by (b-a)^2/12, where a and b are the minimum and maximum values of the distribution, respectively.
#
# The uniform distribution is commonly used in simulations, modeling and Monte Carlo methods, where random values are generated within a given range.
#
# Examples:
# A lottery where each ticket has an equal chance of winning, and the winning numbers are drawn from a uniform distribution.
#
# A random number generator used in computer programming or simulations, where random values are needed within a given range.
#
# A roulette wheel in a casino, where each number has an equal probability of being selected.
#
# The time it takes to complete a task, where each possible time interval within a range has an equal probability of occurring.
#
# The number of customers arriving at a store during a given time period, assuming that customers arrive randomly and independently of each other. In this case, the uniform distribution could be used to model the probability of a customer arriving at any given time within the time period.

# %% [markdown]
# Q8: What is the z score? State the importance of the z score.

# %% [markdown]
# A z-score, also known as a standard score, is a measure of how many standard deviations a given value is from the mean of a distribution.
#
# The formula for calculating the z-score of a value x is z = (x - μ) / σ, where μ is the mean of the distribution and σ is the standard deviation.
#
# The z-score is important because it allows us to standardize different distributions, making it possible to compare values across different scales and distributions.
#
# The z-score can be used to determine the proportion of values that fall above or below a certain threshold, using a standard normal distribution table or calculator.
#
# A z-score of 0 corresponds to a value that is equal to the mean of the distribution, while a z-score of 1 corresponds to a value that is one standard deviation above the mean.
#
# Negative z-scores indicate values that are below the mean, while positive z-scores indicate values that are above the mean.
#
# In addition to comparing values across different distributions, the z-score can also be used to identify outliers or extreme values in a given distribution.

# %% [markdown]
# Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

# %% [markdown]
# The Central Limit Theorem (CLT) is a fundamental concept in statistics that states that the distribution of the sample mean of a large number of independent and identically distributed (IID) random variables will be approximately normally distributed, regardless of the underlying distribution of the original variables.
#
# In other words, if we take multiple random samples of the same size from any distribution (with a finite mean and variance), the distribution of the sample means will become increasingly normal as the sample size increases.
#
# The CLT is significant because it provides a basis for many statistical techniques that rely on the assumption of normality, such as hypothesis testing, confidence intervals, and regression analysis.
#
# It also allows us to make inferences about population parameters, such as the mean and standard deviation, based on a sample of data, even if the underlying distribution is not normal.
#
# The CLT has practical applications in fields such as quality control, finance, and engineering, where it is often necessary to make statistical inferences based on limited sample data.
#
# However, it is important to note that the CLT only applies to the distribution of the sample mean, and not to the distribution of individual observations or other sample statistics, such as the median or mode.

# %% [markdown]
# Q10: State the assumptions of the Central Limit Theorem.

# %% [markdown]
#  key assumptions of the Central Limit Theorem:
#
# The sample size should be sufficiently large. While there is no set minimum sample size required for the CLT to hold, as a rule of thumb, statisticians often use a sample size of 30 or greater.
#
# The sample should be drawn from a population with a finite mean and variance. If the population is infinite or the variance is undefined, the CLT may not hold.
#
# The samples should be independent and identically distributed (IID). This means that each observation in the sample should be drawn randomly from the population and not influenced by any previous observations.
#
# The sampling process should be performed with replacement. This assumption allows the samples to be independent of each other, and ensures that the probability of each observation being selected remains constant across all samples.
#
# If these assumptions are met, the CLT can be used to approximate the distribution of the sample mean as normal, regardless of the underlying distribution of the original variables.
